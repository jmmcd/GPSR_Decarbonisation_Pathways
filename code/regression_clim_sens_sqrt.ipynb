# %% [markdown]
# # Regression - clim_sens and sqrt
#
# In this notebook we create many regression models - baselines and GPSR.
#
# We generate results files.
#
# This notebook requires the output from the data cleaning and data exploration notebooks.
#
# The *main* regression notebook gives main results. This notebook tries some alternate versions: climate sensitivity is truncated and we introduce sqrt to the language.

# %%
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp

from sklearn.model_selection import train_test_split, cross_val_score, cross_validate
from sklearn.linear_model import ElasticNet
from sklearn.ensemble import RandomForestRegressor

from pysr import PySRRegressor # a SOTA GP SR library

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42 # helps produce ACM-compliant figures
matplotlib.rcParams['ps.fonttype'] = 42

# %%
Xy = pd.read_csv("../outputs/data_Xy_clim_sens_filter.csv", index_col=0)

# %%
Xy.columns
# Out:
# Index(['Scenario', 'SOW', 'Temp_Limit', 'Delay', 'GDP', 'Pop',
#        'Other_ESD_Drivers', 'SDR', 'Elast_ESD_Driver', 'Elast_ESD_Price',
#        'CO2_Storage_Poten', 'Wind_Poten', 'Solar_Poten', 'Biomass_Poten',
#        'Oil_Gas_Poten', 'Solar_PV_Inv_Cost', 'Wind_Inv_Cost',
#        'Bioenergy_CCS_Inv_Cost', 'Other_Tech_Cost', 'Forcing', 'Land_Sinks',
#        'Clim_Sens', 'Year', 'Temp_Change', 'Rad_Forcing', 'CO2_Conc',
#        'CH4_Conc', 'N20_Conc', 'Carbon', 'CO2eq', 'Marg_CO2_Cost', 'GSupply',
#        'GSupply_Bioenergy', 'GSupply_Fossil', 'GSupply_Geothermal',
#        'GSupply_Nuclear', 'GSupply_Solar', 'GSupply_Tidal_Waves',
#        'GSupply_Wind', 'GConsumption', 'GConsumption_Fossil',
#        'GConsumption_Nuclear', 'GConsumption_Renewable', 'GCost'],
#       dtype='object')

# %% [markdown]
# ## Experimental Design
#
# We try several target variables (ie dependent variable), several subsets of independent variables, several regression models.
#
# ## Cross-validation
#
# In preliminary experiments we see large differences in performance according to train-test split - therefore, we use a 5-fold cross-validation.
#
# ## Reporting
#
# For each of those 5 folds, we report the train $R^2$ and test $R^2$.

# %%
# We have two sets of variables, 'small' and 'all'
# For each, we have a variant which includes the scenario-encoding variables (_inc_enc)
# and a variant which excludes them.
# The idea is to compare a small versus a large subset for each scenario.
# And then as an alternative, put all the scenarios together, with the scenario-encoding
# variables included, and compare small versus large.
xvar_subsets = {
    'small': ['SDR', 'Clim_Sens', 'Pop', 'GDP'],
    'small_inc_enc': ['Temp_Limit', 'Delay', 'SDR', 'Clim_Sens', 'Pop', 'GDP'],
    'all': ['GDP', 'Pop',
       'Other_ESD_Drivers', 'SDR', 'Elast_ESD_Driver', 'Elast_ESD_Price',
       'CO2_Storage_Poten', 'Wind_Poten', 'Solar_Poten', 'Biomass_Poten',
       'Oil_Gas_Poten', 'Solar_PV_Inv_Cost', 'Wind_Inv_Cost',
       'Bioenergy_CCS_Inv_Cost', 'Other_Tech_Cost', 'Forcing', 'Land_Sinks',
       'Clim_Sens'],
    'all_inc_enc': ['Temp_Limit', 'Delay', 'GDP', 'Pop',
       'Other_ESD_Drivers', 'SDR', 'Elast_ESD_Driver', 'Elast_ESD_Price',
       'CO2_Storage_Poten', 'Wind_Poten', 'Solar_Poten', 'Biomass_Poten',
       'Oil_Gas_Poten', 'Solar_PV_Inv_Cost', 'Wind_Inv_Cost',
       'Bioenergy_CCS_Inv_Cost', 'Other_Tech_Cost', 'Forcing', 'Land_Sinks',
       'Clim_Sens']
}

scenarios = ['BASE_SSP2', '1p5c_OS_SSP2', '2C_SSP2', '2C_SSP2_DA30', 'ALL']

targets = ['GSupply', 'CO2eq', 'GConsumption', 'GCost'] # cannot do marginal CO2 as it's all-NaNs at 2050

# %%
def run_everything(Xy, cv=5):

    results = [] 

    for target in targets:
        for scenario in scenarios:
            if scenario == 'ALL':
                Xy_sub = Xy
            else:
                Xy_sub = Xy[Xy['Scenario'] == scenario]
            for xvar_subset_code in xvar_subsets:

                # for the 'ALL' scenario, run only if we have _inc_enc
                if scenario == 'ALL' and (not "_inc_enc" in xvar_subset_code): continue
                # for the non-ALL scenarios, run only if we DO NOT have _inc_enc
                if scenario != 'ALL' and ("_inc_enc" in xvar_subset_code): continue

                xvar_subset = xvar_subsets[xvar_subset_code]
                X = Xy_sub[xvar_subset]
                y = Xy_sub[target]
                print(f'Scenario {scenario}, xvar code {xvar_subset_code} xvars {xvar_subset}, target {target}')
                print("")


                models = [
                    ElasticNet,
                    RandomForestRegressor,
                    lambda: PySRRegressor(unary_operators=["sqrt"])

                    # would be nice to have several more eg:
                    # FFXRegressor,
                    # PyOperon,
                    # my custom SR implementation
                    # NN
                ]


                models = [m() for m in models]

                for m in models:
                    n = m.__class__.__name__
                    print(n)
                    scores = cross_validate(m, X, y, cv=cv,
                                            return_train_score=True)
                    # print(scores)
                    
                    
                    for fold, (tr, ts) in enumerate(zip(scores['train_score'], scores['test_score'])):
                        row = [target, scenario, xvar_subset_code, n, fold, tr, ts]

                        results.append(row)
    return results

# %%
cv = 5
#results = run_everything(Xy, cv)
results_cols = ['Target', 'Scenario', 'xvar_subset_code', 'Regression Model', 'Fold', 'Train Score', 'Test Score']
results_df = pd.DataFrame(results, columns=results_cols)
results_df['Scenario / Variables'] = results_df['Scenario'] + ' / ' + results_df['xvar_subset_code']
#results_df.to_csv(f'../outputs/results_cv5_EN_RF_2xGP_clim_sens_filter_sqrt.csv')

# %% [markdown]
# Check that the results are the shape we expect:

# %%
results_df.head()
# Out:
#     Target   Scenario xvar_subset_code Regression Model  Fold  Train Score  \
# 0  GSupply  BASE_SSP2            small       ElasticNet     0          0.0
# 1  GSupply  BASE_SSP2            small       ElasticNet     1          0.0
# 2  GSupply  BASE_SSP2            small       ElasticNet     2          0.0
# 3  GSupply  BASE_SSP2            small       ElasticNet     3          0.0
# 4  GSupply  BASE_SSP2            small       ElasticNet     4          0.0
#
#    Test Score Scenario / Variables
# 0   -0.015276    BASE_SSP2 / small
# 1   -0.000236    BASE_SSP2 / small
# 2   -0.003057    BASE_SSP2 / small
# 3   -0.000131    BASE_SSP2 / small
# 4   -0.000925    BASE_SSP2 / small

# %%
results_df.shape
# Out:
# (600, 8)

# %%
5 * 4 * 2 * 4 * 5 # 5 scenarios (incl ALL), 4 targets, 2 xvar subsets (variant in the case of ALL), 4 regression methods, 5 cv folds
# Out:
# 800

# %% [markdown]
# # Statistics

# %%
from scipy.stats import ttest_ind

# %%
models = ['ElasticNet', 'RandomForestRegressor', 'PySRRegressor']
for model in models:
    sub = results_df[(results_df['Regression Model'] == model) & (results_df['Scenario'] != 'ALL')]['Test Score']
    print(f'{model} mean {sub.mean():.2f} std {sub.std():.1f}')
    for model2 in models:
        if model2 != model:
            sub2 = results_df[(results_df['Regression Model'] == model2) & (results_df['Scenario'] != 'ALL')]['Test Score']
            print(f'{model} {model2} {ttest_ind(sub, sub2)}')
# Out:
# ElasticNet mean 0.34 std 0.3
# ElasticNet RandomForestRegressor TtestResult(statistic=-12.587304811321358, pvalue=9.318464867619149e-30, df=318.0)
# ElasticNet PySRRegressor TtestResult(statistic=-10.934171065241669, pvalue=7.764711149562302e-24, df=318.0)
# RandomForestRegressor mean 0.76 std 0.3
# RandomForestRegressor ElasticNet TtestResult(statistic=12.587304811321358, pvalue=9.318464867619149e-30, df=318.0)
# RandomForestRegressor PySRRegressor TtestResult(statistic=0.9210536332860737, pvalue=0.35772063132570475, df=318.0)
# PySRRegressor mean 0.73 std 0.4
# PySRRegressor ElasticNet TtestResult(statistic=10.934171065241669, pvalue=7.764711149562302e-24, df=318.0)
# PySRRegressor RandomForestRegressor TtestResult(statistic=-0.9210536332860737, pvalue=0.35772063132570475, df=318.0)

# %%
for model in models:
    sub1 = results_df[(results_df['Regression Model'] == model) & (results_df['xvar_subset_code'] == 'small')]['Test Score']
    sub2 = results_df[(results_df['Regression Model'] == model) & (results_df['xvar_subset_code'] == 'all')]['Test Score']
    print(f'{model} small {sub1.mean():.2f} v all {sub2.mean():.2f}: {ttest_ind(sub1, sub2)}')
# Out:
# ElasticNet small 0.34 v all 0.34: TtestResult(statistic=-0.05775989959419327, pvalue=0.954012863737026, df=158.0)
# RandomForestRegressor small 0.58 v all 0.95: TtestResult(statistic=-8.540990239490862, pvalue=1.0536351514575162e-14, df=158.0)
# PySRRegressor small 0.52 v all 0.94: TtestResult(statistic=-9.120240976911184, pvalue=3.2899833152730717e-16, df=158.0)

# %%
# plot the individual scenario regression results
for target in targets:

    # we exclude GPAFSRegressor for now
    tmp = results_df[(results_df['Target'] == target) & (results_df['Regression Model'] != 'GPAFSRegressor') 
                     & (results_df['Scenario'] != 'ALL')]

    sns.stripplot(tmp, x='Scenario / Variables', y='Train Score', hue='Regression Model');
    plt.xticks(rotation=45, ha='right')
    plt.ylabel(f'Train $R^2$ on {target}')
    plt.tight_layout()
    plt.savefig(f'../outputs/results_boxplot_cv5_{target}_train_clim_sens_filter_sqrt.pdf')
    plt.close()

    sns.stripplot(tmp, x='Scenario / Variables', y='Test Score', hue='Regression Model');
    plt.xticks(rotation=45, ha='right')
    plt.ylabel(f'Test $R^2$ on {target}')
    plt.tight_layout()
    plt.savefig(f'../outputs/results_boxplot_cv5_{target}_test_clim_sens_filter_sqrt.pdf')
    plt.close()

# %%
# plot the *unified* scenario regression results
for target in targets:

    # we exclude GPAFSRegressor for now
    tmp = results_df[(results_df['Target'] == target) & (results_df['Regression Model'] != 'GPAFSRegressor')
                     & (results_df['Scenario'] == 'ALL')]

    sns.stripplot(tmp, x='Scenario / Variables', y='Train Score', hue='Regression Model');
    plt.xticks(rotation=45, ha='right')
    plt.ylabel(f'Train $R^2$ on {target}')
    plt.tight_layout()
    plt.savefig(f'../outputs/results_boxplot_cv5_{target}_unified_scenarios_train_clim_sens_filter_sqrt.pdf')
    plt.close()

    sns.stripplot(tmp, x='Scenario / Variables', y='Test Score', hue='Regression Model');
    plt.xticks(rotation=45, ha='right')
    plt.ylabel(f'Test $R^2$ on {target}')
    plt.tight_layout()
    plt.savefig(f'../outputs/results_boxplot_cv5_{target}_unified_scenarios_test_clim_sens_filter_sqrt.pdf')
    plt.close()

# %% [markdown]
# # Interpretation of models
#
# ## Variable importance and equation interpretation
#
# In this section, we'll use a single train-test split and do a single run (per scenerio) for each of EN, RF, and SR
# as our goal will not be a comparison of performance but an investigation of variable importance.
#
# We include each scenario and all variables, not including the scenario-encoding variables.
#
# RF gives variable importance directly.
#
# EN does not, but we use abs(coefficient_i) * std(x_i)
#
# SR we'll just store the equations together with their loss and complexity values.

# %%
scenarios = ['BASE_SSP2', '1p5c_OS_SSP2', '2C_SSP2', '2C_SSP2_DA30']

import sympy_latex

for scenario in scenarios:
    Xy_tmp = Xy[Xy['Scenario'] == scenario]
    X = Xy_tmp[xvar_subsets['all']]
    for target in targets:
        y = Xy_tmp[target]
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

        for m in [#RandomForestRegressor(), 
                  #ElasticNet(), 
                  PySRRegressor(unary_operators=["sqrt"]), 
                  #GPAFSRegressor(20000, 4000, 0.5, 30, 5, "symbolic_regression.bnf", 0.3)]:
        ]:

            #m.fit(X_train, y_train)
            #m.score(X_test, y_test)

            if m.__class__.__name__ == 'RandomForestRegressor':
                # importance is given directly by the method
                imps = list(zip(m.feature_names_in_, m.feature_importances_))
                imps.sort(key=lambda x: x[1], reverse=True)
                imps = pd.DataFrame(imps, columns=['Feature', 'Importance'])
                # print, write importances to csv and to tex
                print(imps)
                imps.to_csv(f'../outputs/importances_rf_{scenario}_{target}_clim_sens_filter_sqrt.csv')
                imps['Feature'] = imps['Feature'].str.replace('_', ' ')
                imps.to_latex(f'../outputs/importances_rf_{scenario}_{target}_clim_sens_filter_sqrt.tex', index=False)     
            elif m.__class__.__name__ == 'ElasticNet':
                # importance is abs(coef) * std deviation of the var
                X_std = X_train.std(axis=0)
                imps = np.abs(m.coef_) * X_std
                imps = list(zip(m.feature_names_in_, imps))
                imps.sort(key=lambda x: x[1], reverse=True)
                imps = pd.DataFrame(imps, columns=['Feature', 'Importance'])
                # print, write importances to csv and to tex
                print(imps)
                imps.to_csv(f'../outputs/importances_en_{scenario}_{target}_clim_sens_filter_sqrt.csv')
                imps['Feature'] = imps['Feature'].str.replace('_', ' ')
                imps.to_latex(f'../outputs/importances_en_{scenario}_{target}_clim_sens_filter_sqrt.tex', index=False)
            elif m.__class__.__name__ == 'PySRRegressor' or m.__class__.__name__ == 'GPAFSRegressor':

                if m.__class__.__name__ == 'PySRRegressor': method = 'sr'
                if m.__class__.__name__ == 'GPAFSRegressor': method = 'magpie'

                # print, write original equations to csv
                #print(m.equations_)
                #m.equations_.to_csv(f'../outputs/equations_{method}_{scenario}_{target}_clim_sens_filter_sqrt.csv')
                # eqns = m.equations_

                eqns = pd.read_csv(f'../outputs/equations_{method}_{scenario}_{target}_clim_sens_filter_sqrt.csv')

                # write to latex table, but process first, and only useful columns
                eqns = sympy_latex.process_equations_latex(eqns)
                eqns = eqns[['vars', 'consts', 'complexity', 'loss', 'equation']]
                #eqns['equation'] = eqns['equation'].str.replace('_', ' ')
                eqns.to_latex(f'../outputs/equations_{method}_{scenario}_{target}_3cols_clim_sens_filter_sqrt.tex', index=False)
# Out:
# Oil_Gas_Poten
# {Oil_Gas_Poten}
# \mathrm{OilGasPoten} False
# {\mathrm{OilGasPoten}}
# \mathrm{OilGasPoten} 1 0
# -----
# sqrt(CO2_Storage_Poten)
# {1/2, CO2_Storage_Poten}
# 1/2 True
# \mathrm{CO2StoragePoten} False
# {1/2, \mathrm{CO2StoragePoten}}
# sqrt(\mathrm{CO2StoragePoten}) 1 1
# -----
# 32.90138*Elast_ESD_Driver
# {32.9013800000000, Elast_ESD_Driver}
# 32.90 True
# \mathrm{ElastESDDriver} False
# {32.90, \mathrm{ElastESDDriver}}
# 32.9*\mathrm{ElastESDDriver} 1 1
# -----
# 38.37452*Elast_ESD_Driver - 5.496432
# {Elast_ESD_Driver, -5.49643200000000, 38.3745200000000}
# \mathrm{ElastESDDriver} False
# -5.50 True
# 38.37 True
# {\mathrm{ElastESDDriver}, -5.50, 38.37}
# 38.37*\mathrm{ElastESDDriver} - 5.5 1 2
# -----
# 31.831852*Elast_ESD_Driver*sqrt(GDP)
# {Elast_ESD_Driver, 1/2, GDP, 31.8318520000000}
# \mathrm{GDP} False
# 1/2 True
# \mathrm{ElastESDDriver} False
# 31.83 True
# {\mathrm{GDP}, 1/2, \mathrm{ElastESDDriver}, 31.83}
# 31.83*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) 2 1
# -----
# 37.25576*Elast_ESD_Driver*sqrt(GDP) - 5.718626
# {Elast_ESD_Driver, 1/2, 37.2557600000000, GDP, -5.71862600000000}
# 1/2 True
# 37.26 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# -5.72 True
# {1/2, 37.26, \mathrm{ElastESDDriver}, \mathrm{GDP}, -5.72}
# 37.26*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 5.72 2 3
# -----
# Elast_ESD_Driver*(16.208658*GDP + 21.75721) - 6.2884965
# {Elast_ESD_Driver, GDP, 16.2086580000000, 21.7572100000000, -6.28849650000000}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.21 True
# 21.76 True
# -6.29 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, 16.21, 21.76, -6.29}
# \mathrm{ElastESDDriver}*(16.21*\mathrm{GDP} + 21.76) - 6.29 2 3
# -----
# 37.255604*Elast_ESD_Driver*sqrt(GDP) - 5.7184663/Other_ESD_Drivers
# {Other_ESD_Drivers, Elast_ESD_Driver, 1/2, 37.2556040000000, GDP, -5.71846630000000, -1}
# 1/2 True
# 37.26 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{OtherESDDrivers} False
# -5.72 True
# -1 True
# {1/2, 37.26, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{OtherESDDrivers}, -5.72, -1}
# 37.26*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 5.72/\mathrm{OtherESDDrivers} 3 4
# -----
# Elast_ESD_Driver*(16.208658*GDP + 21.75721) - 6.2884965/Other_ESD_Drivers
# {Other_ESD_Drivers, Elast_ESD_Driver, GDP, 16.2086580000000, 21.7572100000000, -6.28849650000000, -1}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.21 True
# 21.76 True
# \mathrm{OtherESDDrivers} False
# -6.29 True
# -1 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, 16.21, 21.76, \mathrm{OtherESDDrivers}, -6.29, -1}
# (\mathrm{ElastESDDriver}*\mathrm{OtherESDDrivers}*(16.21*\mathrm{GDP} + 21.76) - 6.29)/\mathrm{OtherESDDrivers} 3 4
# -----
# sqrt(GDP)*(38.37452*Elast_ESD_Driver - 5.496432/Other_ESD_Drivers) - 1.25417794
# {1/2, Elast_ESD_Driver, Other_ESD_Drivers, GDP, 38.3745200000000, -5.49643200000000, -1, -1.25417794000000}
# 1/2 True
# 38.37 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{OtherESDDrivers} False
# -5.50 True
# -1 True
# -1.25 True
# {1/2, 38.37, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{OtherESDDrivers}, -5.50, -1, -1.25}
# (sqrt(\mathrm{GDP})*(38.37*\mathrm{ElastESDDriver}*\mathrm{OtherESDDrivers} - 5.5) - 1.25*\mathrm{OtherESDDrivers})/\mathrm{OtherESDDrivers} 3 5
# -----
# Elast_ESD_Driver*(Elast_ESD_Driver + 17.69709*GDP + 17.69709*Other_ESD_Drivers**(1/4)) - Wind_Inv_Cost - 3.874468
# {Elast_ESD_Driver, Other_ESD_Drivers, GDP, Wind_Inv_Cost, 17.6970900000000, 1/4, -3.87446800000000, -1}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 17.70 True
# 1/4 True
# \mathrm{OtherESDDrivers} False
# \mathrm{WindInvCost} False
# -3.87 True
# -1 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, 17.70, 1/4, \mathrm{OtherESDDrivers}, \mathrm{WindInvCost}, -3.87, -1}
# \mathrm{ElastESDDriver}*(\mathrm{ElastESDDriver} + 17.7*\mathrm{GDP} + 17.7*\mathrm{OtherESDDrivers}**(1/4)) - \mathrm{WindInvCost} - 3.87 4 4
# -----
# Elast_ESD_Driver*(Elast_ESD_Driver + 17.69709*GDP + 17.69709*Other_ESD_Drivers**(1/4)) - sqrt(Wind_Inv_Cost) - 3.874468
# {1/2, Elast_ESD_Driver, Other_ESD_Drivers, GDP, Wind_Inv_Cost, 17.6970900000000, 1/4, -3.87446800000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 17.70 True
# 1/4 True
# \mathrm{OtherESDDrivers} False
# \mathrm{WindInvCost} False
# -3.87 True
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, 17.70, 1/4, \mathrm{OtherESDDrivers}, \mathrm{WindInvCost}, -3.87, -1}
# \mathrm{ElastESDDriver}*(\mathrm{ElastESDDriver} + 17.7*\mathrm{GDP} + 17.7*\mathrm{OtherESDDrivers}**(1/4)) - sqrt(\mathrm{WindInvCost}) - 3.87 4 5
# -----
# Elast_ESD_Driver*(Elast_ESD_Driver + 17.69709*GDP + 17.69709*Other_ESD_Drivers**(1/4)) - Wind_Inv_Cost - 3.815711332
# {Elast_ESD_Driver, Other_ESD_Drivers, GDP, Wind_Inv_Cost, 17.6970900000000, 1/4, -3.81571133200000, -1}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 17.70 True
# 1/4 True
# \mathrm{OtherESDDrivers} False
# \mathrm{WindInvCost} False
# -3.82 True
# -1 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, 17.70, 1/4, \mathrm{OtherESDDrivers}, \mathrm{WindInvCost}, -3.82, -1}
# \mathrm{ElastESDDriver}*(\mathrm{ElastESDDriver} + 17.7*\mathrm{GDP} + 17.7*\mathrm{OtherESDDrivers}**(1/4)) - \mathrm{WindInvCost} - 3.82 4 4
# -----
# Clim_Sens
# {Clim_Sens}
# \mathrm{ClimSens} False
# {\mathrm{ClimSens}}
# \mathrm{ClimSens} 1 0
# -----
# 41.81924*Elast_ESD_Driver
# {41.8192400000000, Elast_ESD_Driver}
# 41.82 True
# \mathrm{ElastESDDriver} False
# {41.82, \mathrm{ElastESDDriver}}
# 41.82*\mathrm{ElastESDDriver} 1 1
# -----
# 59.87464*Elast_ESD_Driver - 18.131884
# {Elast_ESD_Driver, 59.8746400000000, -18.1318840000000}
# \mathrm{ElastESDDriver} False
# 59.87 True
# -18.13 True
# {\mathrm{ElastESDDriver}, 59.87, -18.13}
# 59.87*\mathrm{ElastESDDriver} - 18.13 1 2
# -----
# 40.603733*Elast_ESD_Driver*sqrt(GDP)
# {40.6037330000000, Elast_ESD_Driver, 1/2, GDP}
# 40.60 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# {40.60, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}}
# 40.6*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) 2 1
# -----
# 59.87486*Elast_ESD_Driver - 19.174332/GDP
# {Elast_ESD_Driver, GDP, -19.1743320000000, 59.8748600000000, -1}
# \mathrm{ElastESDDriver} False
# -19.17 True
# \mathrm{GDP} False
# 59.87 True
# -1 True
# {\mathrm{ElastESDDriver}, -19.17, \mathrm{GDP}, 59.87, -1}
# 59.87*\mathrm{ElastESDDriver} - 19.17/\mathrm{GDP} 2 3
# -----
# 58.426464*Elast_ESD_Driver*sqrt(GDP) - 18.786623
# {Elast_ESD_Driver, 1/2, GDP, -18.7866230000000, 58.4264640000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# -18.79 True
# \mathrm{GDP} False
# 58.43 True
# {1/2, \mathrm{ElastESDDriver}, -18.79, \mathrm{GDP}, 58.43}
# 58.43*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 18.79 2 3
# -----
# -Biomass_Poten + 58.425396*Elast_ESD_Driver*sqrt(GDP) - 17.773943
# {Elast_ESD_Driver, 1/2, GDP, -17.7739430000000, Biomass_Poten, 58.4253960000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# -17.77 True
# \mathrm{GDP} False
# \mathrm{BiomassPoten} False
# 58.43 True
# -1 True
# {1/2, \mathrm{ElastESDDriver}, -17.77, \mathrm{GDP}, \mathrm{BiomassPoten}, 58.43, -1}
# -\mathrm{BiomassPoten} + 58.43*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 17.77 3 4
# -----
# 28.229763*Elast_ESD_Driver**2*GDP + Other_ESD_Drivers + 10.31128
# {Other_ESD_Drivers, Elast_ESD_Driver, 2, GDP, 10.3112800000000, 28.2297630000000}
# 2 True
# \mathrm{ElastESDDriver} False
# 10.31 True
# \mathrm{GDP} False
# \mathrm{OtherESDDrivers} False
# 28.23 True
# {2, \mathrm{ElastESDDriver}, 10.31, \mathrm{GDP}, \mathrm{OtherESDDrivers}, 28.23}
# 28.23*\mathrm{ElastESDDriver}**2*\mathrm{GDP} + \mathrm{OtherESDDrivers} + 10.31 3 3
# -----
# -Biomass_Poten + Elast_ESD_Driver*(26.22175*Elast_ESD_Driver*GDP + 5.0101476) + 9.581914
# {Elast_ESD_Driver, 5.01014760000000, GDP, 9.58191400000000, Biomass_Poten, 26.2217500000000, -1}
# 5.01 True
# \mathrm{ElastESDDriver} False
# 9.58 True
# \mathrm{GDP} False
# \mathrm{BiomassPoten} False
# 26.22 True
# -1 True
# {5.01, \mathrm{ElastESDDriver}, 9.58, \mathrm{GDP}, \mathrm{BiomassPoten}, 26.22, -1}
# -\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(26.22*\mathrm{ElastESDDriver}*\mathrm{GDP} + 5.01) + 9.58 3 4
# -----
# -Biomass_Poten + Elast_ESD_Driver*(-2*Biomass_Poten + 18.2945173984062*Elast_ESD_Driver + 24.666971221538*GDP)
# {Elast_ESD_Driver, GDP, 18.2945173984062, -2, Biomass_Poten, 24.6669712215380, -1}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 18.29 True
# -2 True
# 24.67 True
# \mathrm{BiomassPoten} False
# -1 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, 18.29, -2, 24.67, \mathrm{BiomassPoten}, -1}
# -\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(-2*\mathrm{BiomassPoten} + 18.29*\mathrm{ElastESDDriver} + 24.67*\mathrm{GDP}) 3 4
# -----
# -Biomass_Poten + Elast_ESD_Driver*(-Biomass_Poten + 26.22175*Elast_ESD_Driver*GDP + 5.0101476) + Land_Sinks + 9.581914
# {Elast_ESD_Driver, 5.01014760000000, GDP, 9.58191400000000, Land_Sinks, Biomass_Poten, 26.2217500000000, -1}
# \mathrm{LandSinks} False
# 5.01 True
# \mathrm{ElastESDDriver} False
# 9.58 True
# \mathrm{GDP} False
# \mathrm{BiomassPoten} False
# 26.22 True
# -1 True
# {\mathrm{LandSinks}, 5.01, \mathrm{ElastESDDriver}, 9.58, \mathrm{GDP}, \mathrm{BiomassPoten}, 26.22, -1}
# -\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(-\mathrm{BiomassPoten} + 26.22*\mathrm{ElastESDDriver}*\mathrm{GDP} + 5.01) + \mathrm{LandSinks} + 9.58 4 4
# -----
# -sqrt(Elast_ESD_Driver) + Elast_ESD_Driver**2*(-Elast_ESD_Price + 26.058739*GDP + 3.7551317) + 12.237931/sqrt(Biomass_Poten)
# {Elast_ESD_Driver, 1/2, 2, 3.75513170000000, GDP, 12.2379310000000, Elast_ESD_Price, Biomass_Poten, 26.0587390000000, -1, -1/2}
# 1/2 True
# 2 True
# 3.76 True
# \mathrm{ElastESDDriver} False
# 12.24 True
# \mathrm{GDP} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# 26.06 True
# -1 True
# -1/2 True
# {1/2, 2, 3.76, \mathrm{ElastESDDriver}, 12.24, \mathrm{GDP}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, 26.06, -1, -1/2}
# (sqrt(\mathrm{BiomassPoten})*(-sqrt(\mathrm{ElastESDDriver}) + \mathrm{ElastESDDriver}**2*(-\mathrm{ElastESDPrice} + 26.06*\mathrm{GDP} + 3.76)) + 12.24)/sqrt(\mathrm{BiomassPoten}) 4 7
# -----
# -sqrt(Elast_ESD_Driver) + Elast_ESD_Driver**2*(-sqrt(Elast_ESD_Price) + 26.058739*GDP + 3.7551317) + 12.237931/sqrt(Biomass_Poten)
# {Elast_ESD_Driver, 1/2, 2, 3.75513170000000, GDP, 12.2379310000000, Elast_ESD_Price, Biomass_Poten, 26.0587390000000, -1, -1/2}
# 1/2 True
# 2 True
# 3.76 True
# \mathrm{ElastESDDriver} False
# 12.24 True
# \mathrm{GDP} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# 26.06 True
# -1 True
# -1/2 True
# {1/2, 2, 3.76, \mathrm{ElastESDDriver}, 12.24, \mathrm{GDP}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, 26.06, -1, -1/2}
# (sqrt(\mathrm{BiomassPoten})*(-sqrt(\mathrm{ElastESDDriver}) + \mathrm{ElastESDDriver}**2*(-sqrt(\mathrm{ElastESDPrice}) + 26.06*\mathrm{GDP} + 3.76)) + 12.24)/sqrt(\mathrm{BiomassPoten}) 4 7
# -----
# Elast_ESD_Driver
# {Elast_ESD_Driver}
# \mathrm{ElastESDDriver} False
# {\mathrm{ElastESDDriver}}
# \mathrm{ElastESDDriver} 1 0
# -----
# 823.55035*Elast_ESD_Driver
# {Elast_ESD_Driver, 823.550350000000}
# \mathrm{ElastESDDriver} False
# 823.55 True
# {\mathrm{ElastESDDriver}, 823.55}
# 823.55*\mathrm{ElastESDDriver} 1 1
# -----
# 946.63104*Elast_ESD_Driver - 122.60554
# {Elast_ESD_Driver, 946.631040000000, -122.605540000000}
# \mathrm{ElastESDDriver} False
# 946.63 True
# -122.61 True
# {\mathrm{ElastESDDriver}, 946.63, -122.61}
# 946.63*\mathrm{ElastESDDriver} - 122.61 1 2
# -----
# 796.0337*Elast_ESD_Driver*sqrt(GDP)
# {Elast_ESD_Driver, 1/2, 796.033700000000, GDP}
# 1/2 True
# 796.03 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# {1/2, 796.03, \mathrm{ElastESDDriver}, \mathrm{GDP}}
# 796.03*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) 2 1
# -----
# 928.3061*Elast_ESD_Driver*sqrt(GDP) - 137.69217
# {928.306100000000, Elast_ESD_Driver, 1/2, GDP, -137.692170000000}
# 928.31 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# -137.69 True
# {928.31, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, -137.69}
# 928.31*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 137.69 2 3
# -----
# 927.2037*Elast_ESD_Driver*sqrt(GDP) + SDR - 140.85388
# {Elast_ESD_Driver, 1/2, GDP, SDR, -140.853880000000, 927.203700000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# -140.85 True
# \mathrm{SDR} False
# 927.20 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, -140.85, \mathrm{SDR}, 927.20}
# 927.2*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) + \mathrm{SDR} - 140.85 3 3
# -----
# 928.33105*Elast_ESD_Driver*sqrt(GDP) - 69.18802 - 68.53088/Other_ESD_Drivers
# {928.331050000000, Other_ESD_Drivers, Elast_ESD_Driver, 1/2, GDP, -69.1880200000000, -68.5308800000000, -1}
# 928.33 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{OtherESDDrivers} False
# -69.19 True
# -68.53 True
# -1 True
# {928.33, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{OtherESDDrivers}, -69.19, -68.53, -1}
# 928.33*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 69.19 - 68.53/\mathrm{OtherESDDrivers} 3 5
# -----
# 928.33105*Elast_ESD_Driver*sqrt(GDP) - 69.18802 - 68.53088/sqrt(Other_ESD_Drivers)
# {928.331050000000, Other_ESD_Drivers, Elast_ESD_Driver, 1/2, GDP, -69.1880200000000, -68.5308800000000, -1/2}
# 928.33 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{OtherESDDrivers} False
# -69.19 True
# -68.53 True
# -1/2 True
# {928.33, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{OtherESDDrivers}, -69.19, -68.53, -1/2}
# 928.33*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 69.19 - 68.53/sqrt(\mathrm{OtherESDDrivers}) 3 5
# -----
# Elast_ESD_Driver*(880.2557*Elast_ESD_Driver*sqrt(GDP) - 857.8143) + 765.5711259
# {Elast_ESD_Driver, 1/2, GDP, -857.814300000000, 880.255700000000, 765.571125900000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# -857.81 True
# \mathrm{GDP} False
# 880.26 True
# 765.57 True
# {1/2, \mathrm{ElastESDDriver}, -857.81, \mathrm{GDP}, 880.26, 765.57}
# \mathrm{ElastESDDriver}*(880.26*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP}) - 857.81) + 765.57 2 4
# -----
# -Bioenergy_CCS_Inv_Cost + Elast_ESD_Driver*(Elast_ESD_Driver*(Biomass_Poten + 880.2557*sqrt(GDP)) - 857.8143) + 765.9762
# {Elast_ESD_Driver, 1/2, GDP, -857.814300000000, Bioenergy_CCS_Inv_Cost, 880.255700000000, Biomass_Poten, 765.976200000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# -857.81 True
# \mathrm{BioenergyCCSInvCost} False
# \mathrm{GDP} False
# 880.26 True
# \mathrm{BiomassPoten} False
# 765.98 True
# -1 True
# {1/2, \mathrm{ElastESDDriver}, -857.81, \mathrm{BioenergyCCSInvCost}, \mathrm{GDP}, 880.26, \mathrm{BiomassPoten}, 765.98, -1}
# -\mathrm{BioenergyCCSInvCost} + \mathrm{ElastESDDriver}*(\mathrm{ElastESDDriver}*(\mathrm{BiomassPoten} + 880.26*sqrt(\mathrm{GDP})) - 857.81) + 765.98 4 5
# -----
# Elast_ESD_Driver*(Elast_ESD_Driver*(sqrt(GDP)*(880.2557 - Forcing) - 1.0160427) + SDR - 857.8143) - GDP + 765.9762
# {Elast_ESD_Driver, 1/2, GDP, Forcing, -857.814300000000, SDR, 880.255700000000, 765.976200000000, -1, -1.01604270000000}
# 1.02 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{SDR} False
# -880.26 True
# 857.81 True
# \mathrm{Forcing} False
# 765.98 True
# -1 True
# {1.02, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{SDR}, -880.26, 857.81, \mathrm{Forcing}, 765.98, -1}
# -\mathrm{ElastESDDriver}*(\mathrm{ElastESDDriver}*(sqrt(\mathrm{GDP})*(\mathrm{Forcing} - 880.26) + 1.02) - \mathrm{SDR} + 857.81) - \mathrm{GDP} + 765.98 4 6
# -----
# Wind_Inv_Cost
# {Wind_Inv_Cost}
# \mathrm{WindInvCost} False
# {\mathrm{WindInvCost}}
# \mathrm{WindInvCost} 1 0
# -----
# sqrt(SDR)
# {1/2, SDR}
# \mathrm{SDR} False
# 1/2 True
# {\mathrm{SDR}, 1/2}
# sqrt(\mathrm{SDR}) 1 1
# -----
# 25.19988*Elast_ESD_Driver
# {25.1998800000000, Elast_ESD_Driver}
# 25.20 True
# \mathrm{ElastESDDriver} False
# {25.20, \mathrm{ElastESDDriver}}
# 25.2*\mathrm{ElastESDDriver} 1 1
# -----
# 21.285921*Elast_ESD_Driver + SDR
# {Elast_ESD_Driver, SDR, 21.2859210000000}
# \mathrm{SDR} False
# 21.29 True
# \mathrm{ElastESDDriver} False
# {\mathrm{SDR}, 21.29, \mathrm{ElastESDDriver}}
# 21.29*\mathrm{ElastESDDriver} + \mathrm{SDR} 2 1
# -----
# 21.087135*Elast_ESD_Driver + GDP*SDR
# {Elast_ESD_Driver, SDR, 21.0871350000000, GDP}
# \mathrm{SDR} False
# 21.09 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# {\mathrm{SDR}, 21.09, \mathrm{ElastESDDriver}, \mathrm{GDP}}
# 21.09*\mathrm{ElastESDDriver} + \mathrm{GDP}*\mathrm{SDR} 3 1
# -----
# Elast_ESD_Driver*sqrt(GDP)*(SDR + 20.18171)
# {Elast_ESD_Driver, 1/2, GDP, SDR, 20.1817100000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 20.18 True
# \mathrm{SDR} False
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, 20.18, \mathrm{SDR}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 20.18) 3 1
# -----
# Elast_ESD_Driver*sqrt(GDP)*(Other_ESD_Drivers*SDR + 20.18171)
# {Other_ESD_Drivers, Elast_ESD_Driver, 1/2, GDP, SDR, 20.1817100000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 20.18 True
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, 20.18, \mathrm{OtherESDDrivers}, \mathrm{SDR}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{OtherESDDrivers}*\mathrm{SDR} + 20.18) 4 1
# -----
# Elast_ESD_Driver*sqrt(GDP)*(20.18171 + Other_ESD_Drivers*SDR/Elast_ESD_Driver)
# {Other_ESD_Drivers, Elast_ESD_Driver, 1/2, GDP, SDR, 20.1817100000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 20.18 True
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, 20.18, \mathrm{OtherESDDrivers}, \mathrm{SDR}}
# sqrt(\mathrm{GDP})*(20.18*\mathrm{ElastESDDriver} + \mathrm{OtherESDDrivers}*\mathrm{SDR}) 4 2
# -----
# Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers - 0.12214077
# {-0.122140770000000, Other_ESD_Drivers, Elast_ESD_Driver, 3.83974150000000, 1/2, GDP, SDR, 16.7500300000000}
# -0.12 True
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# {-0.12, 1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{OtherESDDrivers}, \mathrm{SDR}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} - 0.12 4 4
# -----
# 1.00892*Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers - 0.29867288
# {-0.298672880000000, Other_ESD_Drivers, Elast_ESD_Driver, 3.83974150000000, 1.00892000000000, GDP, 1/2, SDR, 16.7500300000000}
# -0.30 True
# 1.01 True
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# {-0.30, 1.01, 1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{OtherESDDrivers}, \mathrm{SDR}}
# 1.01*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} - 0.3 4 5
# -----
# Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers + Pop - 1.17333533143769
# {Other_ESD_Drivers, Elast_ESD_Driver, 3.83974150000000, 1/2, GDP, SDR, 16.7500300000000, Pop, -1.17333533143769}
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{Pop} False
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# -1.17 True
# {1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{Pop}, \mathrm{OtherESDDrivers}, \mathrm{SDR}, -1.17}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} + \mathrm{Pop} - 1.17 5 4
# -----
# -0.29867288*Biomass_Poten + 1.00892*Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers
# {-0.298672880000000, Other_ESD_Drivers, 1.00892000000000, 3.83974150000000, Elast_ESD_Driver, GDP, 1/2, SDR, 16.7500300000000, Biomass_Poten}
# -0.30 True
# 1.01 True
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{SDR} False
# \mathrm{OtherESDDrivers} False
# \mathrm{BiomassPoten} False
# {-0.30, 1.01, 1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{SDR}, \mathrm{OtherESDDrivers}, \mathrm{BiomassPoten}}
# -0.3*\mathrm{BiomassPoten} + 1.01*\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} 5 5
# -----
# Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers + Pop - 1.17333533143769/Pop
# {Other_ESD_Drivers, Elast_ESD_Driver, 3.83974150000000, 1/2, GDP, SDR, 16.7500300000000, Pop, -1, -1.17333533143769}
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{Pop} False
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# -1 True
# -1.17 True
# {1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{Pop}, \mathrm{OtherESDDrivers}, \mathrm{SDR}, -1, -1.17}
# (\mathrm{Pop}*(\mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} + \mathrm{Pop}) - 1.17)/\mathrm{Pop} 5 5
# -----
# -0.13472515*Biomass_Poten + Elast_ESD_Driver*sqrt(GDP)*(SDR + 16.75003) + 3.8397415*Other_ESD_Drivers + Pop - 0.9811814
# {-0.981181400000000, Other_ESD_Drivers, -0.134725150000000, 3.83974150000000, Elast_ESD_Driver, GDP, 1/2, SDR, 16.7500300000000, Biomass_Poten, Pop}
# -0.98 True
# -0.13 True
# 1/2 True
# 3.84 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 16.75 True
# \mathrm{SDR} False
# \mathrm{Pop} False
# \mathrm{OtherESDDrivers} False
# \mathrm{BiomassPoten} False
# {-0.98, -0.13, 1/2, 3.84, \mathrm{ElastESDDriver}, \mathrm{GDP}, 16.75, \mathrm{SDR}, \mathrm{Pop}, \mathrm{OtherESDDrivers}, \mathrm{BiomassPoten}}
# -0.13*\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(\mathrm{SDR} + 16.75) + 3.84*\mathrm{OtherESDDrivers} + \mathrm{Pop} - 0.98 6 5
# -----
# Other_ESD_Drivers
# {Other_ESD_Drivers}
# \mathrm{OtherESDDrivers} False
# {\mathrm{OtherESDDrivers}}
# \mathrm{OtherESDDrivers} 1 0
# -----
# 1.40926140229554
# {1.40926140229554}
# 1.41 True
# {1.41}
# 1.41 0 1
# -----
# 17.6526370568394*Clim_Sens
# {17.6526370568394, Clim_Sens}
# 17.65 True
# \mathrm{ClimSens} False
# {17.65, \mathrm{ClimSens}}
# 17.65*\mathrm{ClimSens} 1 1
# -----
# 17.8933897523841*Clim_Sens*Elast_ESD_Driver
# {17.8933897523841, Clim_Sens, Elast_ESD_Driver}
# 17.89 True
# \mathrm{ClimSens} False
# \mathrm{ElastESDDriver} False
# {17.89, \mathrm{ClimSens}, \mathrm{ElastESDDriver}}
# 17.89*\mathrm{ClimSens}*\mathrm{ElastESDDriver} 2 1
# -----
# 21.84364*Clim_Sens*Elast_ESD_Driver - 13.021624
# {Elast_ESD_Driver, Clim_Sens, -13.0216240000000, 21.8436400000000}
# \mathrm{ClimSens} False
# -13.02 True
# 21.84 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, -13.02, 21.84, \mathrm{ElastESDDriver}}
# 21.84*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 13.02 2 2
# -----
# 20.2326102737958*Clim_Sens*Elast_ESD_Driver - 2*SDR
# {Elast_ESD_Driver, Clim_Sens, SDR, 20.2326102737958, -2}
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 20.23 True
# \mathrm{SDR} False
# -2 True
# {\mathrm{ElastESDDriver}, \mathrm{ClimSens}, 20.23, \mathrm{SDR}, -2}
# 20.23*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 2*\mathrm{SDR} 3 2
# -----
# sqrt(Elast_ESD_Driver)*(19.0983508153907*Clim_Sens*Elast_ESD_Driver - SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, SDR, 19.0983508153907, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 19.10 True
# \mathrm{SDR} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{ClimSens}, 19.10, \mathrm{SDR}, -1}
# sqrt(\mathrm{ElastESDDriver})*(19.1*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - \mathrm{SDR}) 3 2
# -----
# Elast_ESD_Driver**2*(19.8650712710088*Clim_Sens - 2*SDR)
# {Elast_ESD_Driver, 2, Clim_Sens, SDR, 19.8650712710088, -2}
# 2 True
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 19.87 True
# \mathrm{SDR} False
# -2 True
# {2, \mathrm{ElastESDDriver}, \mathrm{ClimSens}, 19.87, \mathrm{SDR}, -2}
# \mathrm{ElastESDDriver}**2*(19.87*\mathrm{ClimSens} - 2*\mathrm{SDR}) 3 3
# -----
# sqrt(Elast_ESD_Driver)*(Elast_ESD_Driver*(20.2326102737958*Clim_Sens - SDR) - SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, SDR, 20.2326102737958, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 20.23 True
# \mathrm{SDR} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{ClimSens}, 20.23, \mathrm{SDR}, -1}
# sqrt(\mathrm{ElastESDDriver})*(\mathrm{ElastESDDriver}*(20.23*\mathrm{ClimSens} - \mathrm{SDR}) - \mathrm{SDR}) 3 2
# -----
# sqrt(Elast_ESD_Driver*GDP)*(19.8650712710088*Clim_Sens*Elast_ESD_Driver - 2*SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, 19.8650712710088, -2}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 19.87 True
# \mathrm{SDR} False
# -2 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 19.87, \mathrm{SDR}, -2}
# sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(19.87*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 2*\mathrm{SDR}) 4 2
# -----
# sqrt(Elast_ESD_Driver)*sqrt(GDP)*(Elast_ESD_Driver*(19.8650712710088*Clim_Sens - SDR) - SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, 19.8650712710088, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 19.87 True
# \mathrm{SDR} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 19.87, \mathrm{SDR}, -1}
# sqrt(\mathrm{ElastESDDriver})*sqrt(\mathrm{GDP})*(\mathrm{ElastESDDriver}*(19.87*\mathrm{ClimSens} - \mathrm{SDR}) - \mathrm{SDR}) 4 2
# -----
# -Biomass_Poten + sqrt(Elast_ESD_Driver*GDP)*(19.8650712710088*Clim_Sens*Elast_ESD_Driver - 2*SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, 19.8650712710088, -2, Biomass_Poten, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{SDR} False
# \mathrm{ClimSens} False
# 19.87 True
# -2 True
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{SDR}, \mathrm{ClimSens}, 19.87, -2, \mathrm{BiomassPoten}, -1}
# -\mathrm{BiomassPoten} + sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(19.87*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 2*\mathrm{SDR}) 5 4
# -----
# sqrt(Elast_ESD_Driver*GDP)*(19.8650712710088*Clim_Sens*Elast_ESD_Driver + Other_Tech_Cost - 2.52760158378677*SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, Other_Tech_Cost, 19.8650712710088, -2.52760158378677}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 19.87 True
# \mathrm{SDR} False
# \mathrm{OtherTechCost} False
# -2.53 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 19.87, \mathrm{SDR}, \mathrm{OtherTechCost}, -2.53}
# sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(19.87*\mathrm{ClimSens}*\mathrm{ElastESDDriver} + \mathrm{OtherTechCost} - 2.53*\mathrm{SDR}) 5 2
# -----
# sqrt(Elast_ESD_Driver*GDP)*(19.8650712710088*Clim_Sens*Elast_ESD_Driver + sqrt(Other_Tech_Cost) - 2.52760158378677*SDR)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, Other_Tech_Cost, 19.8650712710088, -2.52760158378677}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 19.87 True
# \mathrm{SDR} False
# \mathrm{OtherTechCost} False
# -2.53 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 19.87, \mathrm{SDR}, \mathrm{OtherTechCost}, -2.53}
# sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(19.87*\mathrm{ClimSens}*\mathrm{ElastESDDriver} + sqrt(\mathrm{OtherTechCost}) - 2.53*\mathrm{SDR}) 5 2
# -----
# sqrt(Elast_ESD_Driver*GDP)*(19.8650712710088*Clim_Sens*Elast_ESD_Driver - 2.52760158378677*SDR + Wind_Poten - 0.10766299)
# {-0.107662990000000, Elast_ESD_Driver, 1/2, Clim_Sens, GDP, Wind_Poten, SDR, 19.8650712710088, -2.52760158378677}
# -0.11 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 19.87 True
# -2.53 True
# \mathrm{SDR} False
# \mathrm{WindPoten} False
# {-0.11, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 19.87, -2.53, \mathrm{SDR}, \mathrm{WindPoten}}
# sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(19.87*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 2.53*\mathrm{SDR} + \mathrm{WindPoten} - 0.11) 5 3
# -----
# Wind_Inv_Cost
# {Wind_Inv_Cost}
# \mathrm{WindInvCost} False
# {\mathrm{WindInvCost}}
# \mathrm{WindInvCost} 1 0
# -----
# 0.250111465151040
# {0.250111465151040}
# 0.25 True
# {0.25}
# 0.25 0 1
# -----
# -2.518439*Clim_Sens
# {Clim_Sens, -2.51843900000000}
# \mathrm{ClimSens} False
# -2.52 True
# {\mathrm{ClimSens}, -2.52}
# -2.52*\mathrm{ClimSens} 1 1
# -----
# 31.637568 - 12.132993*Clim_Sens
# {Clim_Sens, -12.1329930000000, 31.6375680000000}
# \mathrm{ClimSens} False
# -12.13 True
# 31.64 True
# {\mathrm{ClimSens}, -12.13, 31.64}
# 31.64 - 12.13*\mathrm{ClimSens} 1 2
# -----
# Biomass_Poten*(-43.811653 + 113.448845/Clim_Sens)
# {Clim_Sens, 113.448845000000, -43.8116530000000, Biomass_Poten, -1}
# \mathrm{ClimSens} False
# 113.45 True
# -43.81 True
# \mathrm{BiomassPoten} False
# -1 True
# {\mathrm{ClimSens}, 113.45, -43.81, \mathrm{BiomassPoten}, -1}
# -43.81*\mathrm{BiomassPoten} + 113.45*\mathrm{BiomassPoten}/\mathrm{ClimSens} 2 3
# -----
# -Biomass_Poten - 26.443424 + 180.6297/Clim_Sens**2
# {Clim_Sens, -26.4434240000000, 180.629700000000, -2, Biomass_Poten, -1}
# -26.44 True
# \mathrm{ClimSens} False
# 180.63 True
# -2 True
# \mathrm{BiomassPoten} False
# -1 True
# {-26.44, \mathrm{ClimSens}, 180.63, -2, \mathrm{BiomassPoten}, -1}
# -\mathrm{BiomassPoten} - 26.44 + 180.63/\mathrm{ClimSens}**2 2 4
# -----
# Biomass_Poten*(6.239804*Clim_Sens - 85.73158 + 180.6297/Clim_Sens)
# {Clim_Sens, 6.23980400000000, -85.7315800000000, 180.629700000000, Biomass_Poten, -1}
# 6.24 True
# -85.73 True
# \mathrm{ClimSens} False
# 180.63 True
# \mathrm{BiomassPoten} False
# -1 True
# {6.24, -85.73, \mathrm{ClimSens}, 180.63, \mathrm{BiomassPoten}, -1}
# \mathrm{BiomassPoten}*(\mathrm{ClimSens}*(6.24*\mathrm{ClimSens} - 85.73) + 180.63)/\mathrm{ClimSens} 2 4
# -----
# sqrt(Biomass_Poten)*(6.239804*Clim_Sens - 85.73158 + 180.6297/Clim_Sens)
# {1/2, Clim_Sens, 6.23980400000000, -85.7315800000000, 180.629700000000, Biomass_Poten, -1}
# 1/2 True
# 6.24 True
# -85.73 True
# \mathrm{ClimSens} False
# 180.63 True
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, 6.24, -85.73, \mathrm{ClimSens}, 180.63, \mathrm{BiomassPoten}, -1}
# sqrt(\mathrm{BiomassPoten})*(\mathrm{ClimSens}*(6.24*\mathrm{ClimSens} - 85.73) + 180.63)/\mathrm{ClimSens} 2 4
# -----
# Biomass_Poten*(6.771223*Clim_Sens - 87.149185 + 176.30391/Clim_Sens) + 1.3358364
# {1.33583640000000, Clim_Sens, 6.77122300000000, -87.1491850000000, 176.303910000000, Biomass_Poten, -1}
# 1.34 True
# 6.77 True
# -87.15 True
# 176.30 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# -1 True
# {1.34, 6.77, -87.15, 176.30, \mathrm{ClimSens}, \mathrm{BiomassPoten}, -1}
# (\mathrm{BiomassPoten}*(\mathrm{ClimSens}*(6.77*\mathrm{ClimSens} - 87.15) + 176.3) + 1.34*\mathrm{ClimSens})/\mathrm{ClimSens} 2 5
# -----
# sqrt(Biomass_Poten)*(6.239804*Clim_Sens - 85.12867103 + 178.07895/Clim_Sens)
# {1/2, Clim_Sens, 6.23980400000000, -85.1286710300000, 178.078950000000, Biomass_Poten, -1}
# 1/2 True
# 6.24 True
# -85.13 True
# \mathrm{ClimSens} False
# 178.08 True
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, 6.24, -85.13, \mathrm{ClimSens}, 178.08, \mathrm{BiomassPoten}, -1}
# sqrt(\mathrm{BiomassPoten})*(\mathrm{ClimSens}*(6.24*\mathrm{ClimSens} - 85.13) + 178.08)/\mathrm{ClimSens} 2 4
# -----
# sqrt(Biomass_Poten)*(7.1439443*Clim_Sens - sqrt(Solar_PV_Inv_Cost) - 90.19581 + 187.7006/Clim_Sens)
# {1/2, Clim_Sens, -90.1958100000000, 7.14394430000000, Solar_PV_Inv_Cost, Biomass_Poten, 187.700600000000, -1}
# 1/2 True
# \mathrm{SolarPVInvCost} False
# -90.20 True
# 7.14 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# 187.70 True
# -1 True
# {1/2, \mathrm{SolarPVInvCost}, -90.20, 7.14, \mathrm{ClimSens}, \mathrm{BiomassPoten}, 187.70, -1}
# sqrt(\mathrm{BiomassPoten})*(\mathrm{ClimSens}*(7.14*\mathrm{ClimSens} - sqrt(\mathrm{SolarPVInvCost}) - 90.2) + 187.7)/\mathrm{ClimSens} 3 4
# -----
# sqrt(Biomass_Poten)*(7.1439443*Clim_Sens - 90.19581 - sqrt(Solar_PV_Inv_Cost)/Oil_Gas_Poten + 187.7006/Clim_Sens)
# {1/2, Clim_Sens, -90.1958100000000, 7.14394430000000, Oil_Gas_Poten, Solar_PV_Inv_Cost, Biomass_Poten, 187.700600000000, -1}
# 1/2 True
# \mathrm{SolarPVInvCost} False
# -90.20 True
# 7.14 True
# 187.70 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# \mathrm{OilGasPoten} False
# -1 True
# {1/2, \mathrm{SolarPVInvCost}, -90.20, 7.14, 187.70, \mathrm{ClimSens}, \mathrm{BiomassPoten}, \mathrm{OilGasPoten}, -1}
# sqrt(\mathrm{BiomassPoten})*(\mathrm{ClimSens}*\mathrm{OilGasPoten}*(7.14*\mathrm{ClimSens} - 90.2) - \mathrm{ClimSens}*sqrt(\mathrm{SolarPVInvCost}) + 187.7*\mathrm{OilGasPoten})/(\mathrm{ClimSens}*\mathrm{OilGasPoten}) 4 4
# -----
# sqrt(Biomass_Poten)*(6.239804*Clim_Sens - 85.73158 + 178.07895/Clim_Sens) - Biomass_Poten + 1.67678083
# {1.67678083000000, 1/2, Clim_Sens, 6.23980400000000, -85.7315800000000, 178.078950000000, Biomass_Poten, -1}
# 1/2 True
# 1.68 True
# 6.24 True
# -85.73 True
# \mathrm{ClimSens} False
# 178.08 True
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, 1.68, 6.24, -85.73, \mathrm{ClimSens}, 178.08, \mathrm{BiomassPoten}, -1}
# (sqrt(\mathrm{BiomassPoten})*(\mathrm{ClimSens}*(6.24*\mathrm{ClimSens} - 85.73) + 178.08) + \mathrm{ClimSens}*(1.68 - \mathrm{BiomassPoten}))/\mathrm{ClimSens} 2 6
# -----
# -1.05627013590274*Clim_Sens*(2.2765424*Biomass_Poten - 8.91014) - 90.4123826385543 + 188.200582895326/Clim_Sens
# {Clim_Sens, 2.27654240000000, -90.4123826385543, Biomass_Poten, -8.91014000000000, 188.200582895326, -1, -1.05627013590274}
# -90.41 True
# 9.45 True
# \mathrm{ClimSens} False
# -2.42 True
# \mathrm{BiomassPoten} False
# 188.20 True
# -1 True
# {-90.41, 9.45, \mathrm{ClimSens}, -2.42, \mathrm{BiomassPoten}, 188.20, -1}
# -2.42*\mathrm{BiomassPoten}*\mathrm{ClimSens} + 9.45*\mathrm{ClimSens} - 90.41 + 188.2/\mathrm{ClimSens} 2 6
# -----
# 0.283561700000000
# {0.283561700000000}
# 0.28 True
# {0.28}
# 0.28 0 1
# -----
# 28.4593850952546
# {28.4593850952546}
# 28.46 True
# {28.46}
# 28.46 0 1
# -----
# 809.9366*Elast_ESD_Driver
# {809.936600000000, Elast_ESD_Driver}
# 809.94 True
# \mathrm{ElastESDDriver} False
# {809.94, \mathrm{ElastESDDriver}}
# 809.94*\mathrm{ElastESDDriver} 1 1
# -----
# Elast_ESD_Driver*(Clim_Sens + 806.8166)
# {Elast_ESD_Driver, Clim_Sens, 806.816600000000}
# 806.82 True
# \mathrm{ClimSens} False
# \mathrm{ElastESDDriver} False
# {806.82, \mathrm{ClimSens}, \mathrm{ElastESDDriver}}
# \mathrm{ElastESDDriver}*(\mathrm{ClimSens} + 806.82) 2 1
# -----
# Elast_ESD_Driver*(982.14264 - 514.75165/Clim_Sens)
# {Elast_ESD_Driver, Clim_Sens, 982.142640000000, -1, -514.751650000000}
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 982.14 True
# -1 True
# -514.75 True
# {\mathrm{ElastESDDriver}, \mathrm{ClimSens}, 982.14, -1, -514.75}
# \mathrm{ElastESDDriver}*(982.14*\mathrm{ClimSens} - 514.75)/\mathrm{ClimSens} 2 3
# -----
# Biomass_Poten + Elast_ESD_Driver*(54.00349*Clim_Sens + 639.7431)
# {Elast_ESD_Driver, Clim_Sens, 54.0034900000000, Biomass_Poten, 639.743100000000}
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 54.0000000000000 True
# \mathrm{BiomassPoten} False
# 639.74 True
# {\mathrm{ElastESDDriver}, \mathrm{ClimSens}, 54.0000000000000, \mathrm{BiomassPoten}, 639.74}
# \mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(54.0*\mathrm{ClimSens} + 639.74) 3 2
# -----
# Elast_ESD_Driver*sqrt(GDP)*(53.7878*Clim_Sens + 627.55865)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 627.558650000000, 53.7878000000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 627.56 True
# 53.79 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 627.56, 53.79}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(53.79*\mathrm{ClimSens} + 627.56) 3 2
# -----
# Elast_ESD_Driver*GDP**(1/4)*(53.7878*Clim_Sens + 627.55865)
# {Elast_ESD_Driver, Clim_Sens, GDP, 1/4, 627.558650000000, 53.7878000000000}
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 1/4 True
# 627.56 True
# 53.79 True
# {\mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 1/4, 627.56, 53.79}
# \mathrm{ElastESDDriver}*\mathrm{GDP}**(1/4)*(53.79*\mathrm{ClimSens} + 627.56) 3 2
# -----
# Elast_ESD_Driver*sqrt(GDP)*(53.566532*Clim_Sens + 615.0892) - GDP
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 615.089200000000, 53.5665320000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 615.09 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 53.57 True
# -1 True
# {1/2, \mathrm{ElastESDDriver}, 615.09, \mathrm{GDP}, \mathrm{ClimSens}, 53.57, -1}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(53.57*\mathrm{ClimSens} + 615.09) - \mathrm{GDP} 3 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(46.909485*Biomass_Poten*Clim_Sens + 624.7) - SDR
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, 46.9094850000000, 624.700000000000, Biomass_Poten, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 46.91 True
# \mathrm{GDP} False
# 624.70 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# \mathrm{SDR} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, 46.91, \mathrm{GDP}, 624.70, \mathrm{ClimSens}, \mathrm{BiomassPoten}, \mathrm{SDR}, -1}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(46.91*\mathrm{BiomassPoten}*\mathrm{ClimSens} + 624.7) - \mathrm{SDR} 5 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(46.909485*sqrt(Biomass_Poten)*Clim_Sens + 624.7) + Pop
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 46.9094850000000, 624.700000000000, Biomass_Poten, Pop}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 46.91 True
# \mathrm{GDP} False
# 624.70 True
# \mathrm{ClimSens} False
# \mathrm{Pop} False
# \mathrm{BiomassPoten} False
# {1/2, \mathrm{ElastESDDriver}, 46.91, \mathrm{GDP}, 624.70, \mathrm{ClimSens}, \mathrm{Pop}, \mathrm{BiomassPoten}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(46.91*sqrt(\mathrm{BiomassPoten})*\mathrm{ClimSens} + 624.7) + \mathrm{Pop} 5 3
# -----
# Elast_ESD_Driver*sqrt(GDP)*(46.909485*sqrt(Biomass_Poten)*Clim_Sens + 624.7) + 1.264943556053
# {1.26494355605300, 1/2, Elast_ESD_Driver, Clim_Sens, GDP, 46.9094850000000, 624.700000000000, Biomass_Poten}
# 1.26 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# 46.91 True
# \mathrm{GDP} False
# 624.70 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# {1.26, 1/2, \mathrm{ElastESDDriver}, 46.91, \mathrm{GDP}, 624.70, \mathrm{ClimSens}, \mathrm{BiomassPoten}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(46.91*sqrt(\mathrm{BiomassPoten})*\mathrm{ClimSens} + 624.7) + 1.26 4 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(46.909485*sqrt(Biomass_Poten)*Clim_Sens*Pop + 624.7) - Elast_ESD_Price
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 46.9094850000000, 624.700000000000, Elast_ESD_Price, Biomass_Poten, Pop, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 46.91 True
# \mathrm{GDP} False
# 624.70 True
# \mathrm{ClimSens} False
# \mathrm{Pop} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, 46.91, \mathrm{GDP}, 624.70, \mathrm{ClimSens}, \mathrm{Pop}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, -1}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(46.91*sqrt(\mathrm{BiomassPoten})*\mathrm{ClimSens}*\mathrm{Pop} + 624.7) - \mathrm{ElastESDPrice} 6 4
# -----
# -sqrt(Clim_Sens) + Elast_ESD_Driver*sqrt(GDP)*(48.4358554*sqrt(Biomass_Poten)*Clim_Sens + 624.7)
# {1/2, Clim_Sens, Elast_ESD_Driver, GDP, 624.700000000000, 48.4358554000000, Biomass_Poten, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# 624.70 True
# \mathrm{ClimSens} False
# 48.44 True
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, 624.70, \mathrm{ClimSens}, 48.44, \mathrm{BiomassPoten}, -1}
# -sqrt(\mathrm{ClimSens}) + \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(48.44*sqrt(\mathrm{BiomassPoten})*\mathrm{ClimSens} + 624.7) 4 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(46.909485*sqrt(Biomass_Poten)*Clim_Sens*Pop + 626.3136885) - Elast_ESD_Price
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 46.9094850000000, Elast_ESD_Price, 626.313688500000, Biomass_Poten, Pop, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 46.91 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 626.31 True
# \mathrm{Pop} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, 46.91, \mathrm{GDP}, \mathrm{ClimSens}, 626.31, \mathrm{Pop}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, -1}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(46.91*sqrt(\mathrm{BiomassPoten})*\mathrm{ClimSens}*\mathrm{Pop} + 626.31) - \mathrm{ElastESDPrice} 6 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(288.26825*Biomass_Poten + Clim_Sens*(120.991104 - 61.167538*Biomass_Poten) + 297.52847) - Solar_PV_Inv_Cost
# {288.268250000000, Elast_ESD_Driver, 1/2, Clim_Sens, -61.1675380000000, GDP, 297.528470000000, Biomass_Poten, Solar_PV_Inv_Cost, 120.991104000000, -1}
# 288.27 True
# 1/2 True
# \mathrm{SolarPVInvCost} False
# \mathrm{ElastESDDriver} False
# -120.99 True
# 297.53 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# 61.17 True
# -1 True
# {288.27, 1/2, \mathrm{SolarPVInvCost}, \mathrm{ElastESDDriver}, -120.99, 297.53, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{BiomassPoten}, 61.17, -1}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(288.27*\mathrm{BiomassPoten} - \mathrm{ClimSens}*(61.17*\mathrm{BiomassPoten} - 120.99) + 297.53) - \mathrm{SolarPVInvCost} 5 6
# -----
# -0.686477700000000
# {-0.686477700000000}
# -0.69 True
# {-0.69}
# -0.69 0 1
# -----
# sqrt(Clim_Sens)
# {1/2, Clim_Sens}
# \mathrm{ClimSens} False
# 1/2 True
# {\mathrm{ClimSens}, 1/2}
# sqrt(\mathrm{ClimSens}) 1 1
# -----
# Clim_Sens + 35.027927
# {Clim_Sens, 35.0279270000000}
# \mathrm{ClimSens} False
# 35.03 True
# {\mathrm{ClimSens}, 35.03}
# \mathrm{ClimSens} + 35.03 1 1
# -----
# 12.2727049029333*Clim_Sens*Elast_ESD_Driver
# {Elast_ESD_Driver, Clim_Sens, 12.2727049029333}
# \mathrm{ClimSens} False
# 12.27 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, 12.27, \mathrm{ElastESDDriver}}
# 12.27*\mathrm{ClimSens}*\mathrm{ElastESDDriver} 2 1
# -----
# 12.2638809980012*Clim_Sens*Elast_ESD_Driver
# {Elast_ESD_Driver, Clim_Sens, 12.2638809980012}
# \mathrm{ClimSens} False
# 12.26 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, 12.26, \mathrm{ElastESDDriver}}
# 12.26*\mathrm{ClimSens}*\mathrm{ElastESDDriver} 2 1
# -----
# 13.7188005323443*Elast_ESD_Driver*(Clim_Sens - 0.35233298)
# {-0.352332980000000, Elast_ESD_Driver, Clim_Sens, 13.7188005323443}
# -0.35 True
# \mathrm{ClimSens} False
# 13.72 True
# \mathrm{ElastESDDriver} False
# {-0.35, \mathrm{ClimSens}, 13.72, \mathrm{ElastESDDriver}}
# 13.72*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} - 0.35) 2 2
# -----
# 14.1617784927902*Elast_ESD_Driver*(Clim_Sens - 0.7029027) + SDR
# {-0.702902700000000, Elast_ESD_Driver, Clim_Sens, SDR, 14.1617784927902}
# -0.70 True
# \mathrm{ElastESDDriver} False
# 14.16 True
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {-0.70, \mathrm{ElastESDDriver}, 14.16, \mathrm{ClimSens}, \mathrm{SDR}}
# 14.16*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} - 0.7) + \mathrm{SDR} 3 2
# -----
# 14.0807357849058*Elast_ESD_Driver*(Clim_Sens - 0.7169918) + SDR + 0.23785497
# {0.237854970000000, Elast_ESD_Driver, -0.716991800000000, Clim_Sens, SDR, 14.0807357849058}
# 0.24 True
# -0.72 True
# \mathrm{ElastESDDriver} False
# 14.08 True
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {0.24, -0.72, \mathrm{ElastESDDriver}, 14.08, \mathrm{ClimSens}, \mathrm{SDR}}
# 14.08*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} - 0.72) + \mathrm{SDR} + 0.24 3 3
# -----
# 13.7188005323443*Elast_ESD_Driver*(Clim_Sens - 0.7821211) + sqrt(SDR) + SDR
# {-0.782121100000000, 1/2, Elast_ESD_Driver, Clim_Sens, SDR, 13.7188005323443}
# -0.78 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# 13.72 True
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {-0.78, 1/2, \mathrm{ElastESDDriver}, 13.72, \mathrm{ClimSens}, \mathrm{SDR}}
# 13.72*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} - 0.78) + sqrt(\mathrm{SDR}) + \mathrm{SDR} 3 2
# -----
# 13.7188005323443*Elast_ESD_Driver*(Clim_Sens - 0.74686044/GDP) + SDR + 0.863197
# {0.863197000000000, Elast_ESD_Driver, Clim_Sens, -0.746860440000000, GDP, SDR, 13.7188005323443, -1}
# 0.86 True
# \mathrm{ElastESDDriver} False
# 13.72 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# -10.29 True
# \mathrm{SDR} False
# -1 True
# {0.86, \mathrm{ElastESDDriver}, 13.72, \mathrm{GDP}, \mathrm{ClimSens}, -10.29, \mathrm{SDR}, -1}
# 13.72*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - 10.29*\mathrm{ElastESDDriver}/\mathrm{GDP} + \mathrm{SDR} + 0.86 4 4
# -----
# Clim_Sens*Elast_ESD_Driver*(Clim_Sens + 2*GDP + 5.4570527) + SDR + 0.12943006
# {0.129430060000000, Elast_ESD_Driver, Clim_Sens, 2, 5.45705270000000, GDP, SDR}
# 0.13 True
# 2 True
# 5.46 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {0.13, 2, 5.46, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{SDR}}
# \mathrm{ClimSens}*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} + 2*\mathrm{GDP} + 5.46) + \mathrm{SDR} + 0.13 4 3
# -----
# 0.20047472*CO2_Storage_Poten + Elast_ESD_Driver*sqrt(GDP)*(13.7188005323443*Clim_Sens - 10.0225255845341) + SDR
# {0.200474720000000, Elast_ESD_Driver, 1/2, Clim_Sens, GDP, SDR, 13.7188005323443, -10.0225255845341, CO2_Storage_Poten}
# 0.20 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{CO2StoragePoten} False
# 13.72 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# -10.02 True
# \mathrm{SDR} False
# {0.20, 1/2, \mathrm{ElastESDDriver}, \mathrm{CO2StoragePoten}, 13.72, \mathrm{GDP}, \mathrm{ClimSens}, -10.02, \mathrm{SDR}}
# 0.2*\mathrm{CO2StoragePoten} + \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(13.72*\mathrm{ClimSens} - 10.02) + \mathrm{SDR} 5 4
# -----
# Clim_Sens*(Elast_ESD_Driver*(Clim_Sens + Other_ESD_Drivers + 5.4570527) + GDP) + GDP*SDR + 0.030106302
# {0.0301063020000000, Elast_ESD_Driver, Clim_Sens, Other_ESD_Drivers, GDP, 5.45705270000000, SDR}
# 0.03 True
# 5.46 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{OtherESDDrivers} False
# \mathrm{SDR} False
# {0.03, 5.46, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{OtherESDDrivers}, \mathrm{SDR}}
# \mathrm{ClimSens}*(\mathrm{ElastESDDriver}*(\mathrm{ClimSens} + \mathrm{OtherESDDrivers} + 5.46) + \mathrm{GDP}) + \mathrm{GDP}*\mathrm{SDR} + 0.03 5 2
# -----
# Other_Tech_Cost
# {Other_Tech_Cost}
# \mathrm{OtherTechCost} False
# {\mathrm{OtherTechCost}}
# \mathrm{OtherTechCost} 1 0
# -----
# 40.45589*Elast_ESD_Driver
# {40.4558900000000, Elast_ESD_Driver}
# 40.46 True
# \mathrm{ElastESDDriver} False
# {40.46, \mathrm{ElastESDDriver}}
# 40.46*\mathrm{ElastESDDriver} 1 1
# -----
# 12.795998*Clim_Sens*Elast_ESD_Driver
# {Elast_ESD_Driver, Clim_Sens, 12.7959980000000}
# \mathrm{ClimSens} False
# 12.80 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, 12.80, \mathrm{ElastESDDriver}}
# 12.8*\mathrm{ClimSens}*\mathrm{ElastESDDriver} 2 1
# -----
# 9.711557*Elast_ESD_Driver*(Clim_Sens + Elast_ESD_Driver)
# {9.71155700000000, Clim_Sens, Elast_ESD_Driver}
# 9.71 True
# \mathrm{ClimSens} False
# \mathrm{ElastESDDriver} False
# {9.71, \mathrm{ClimSens}, \mathrm{ElastESDDriver}}
# 9.71*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} + \mathrm{ElastESDDriver}) 2 1
# -----
# Elast_ESD_Driver*(1.5874281*Clim_Sens**2 + 23.22201)
# {Elast_ESD_Driver, Clim_Sens, 2, 1.58742810000000, 23.2220100000000}
# 1.59 True
# 2 True
# \mathrm{ElastESDDriver} False
# \mathrm{ClimSens} False
# 23.22 True
# {1.59, 2, \mathrm{ElastESDDriver}, \mathrm{ClimSens}, 23.22}
# \mathrm{ElastESDDriver}*(1.59*\mathrm{ClimSens}**2 + 23.22) 2 3
# -----
# Elast_ESD_Driver*(1.5802838*Clim_Sens**2*GDP + 23.22201)
# {Elast_ESD_Driver, Clim_Sens, 1.58028380000000, 2, GDP, 23.2220100000000}
# 1.58 True
# 2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 23.22 True
# {1.58, 2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 23.22}
# \mathrm{ElastESDDriver}*(1.58*\mathrm{ClimSens}**2*\mathrm{GDP} + 23.22) 3 3
# -----
# Elast_ESD_Driver*(1.5874281*Clim_Sens**2 + 23.22201*sqrt(GDP))
# {Elast_ESD_Driver, Clim_Sens, 2, 1.58742810000000, GDP, 1/2, 23.2220100000000}
# 1.59 True
# 2 True
# 1/2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 23.22 True
# {1.59, 2, 1/2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, 23.22}
# \mathrm{ElastESDDriver}*(1.59*\mathrm{ClimSens}**2 + 23.22*sqrt(\mathrm{GDP})) 3 4
# -----
# Elast_ESD_Driver*(1.5407277*Clim_Sens**2 + 11.9771509495904*Elast_ESD_Driver + 11.9771509495904*GDP)
# {Elast_ESD_Driver, Clim_Sens, 1.54072770000000, 2, GDP, 11.9771509495904}
# 1.54 True
# 2 True
# \mathrm{ElastESDDriver} False
# 11.98 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# {1.54, 2, \mathrm{ElastESDDriver}, 11.98, \mathrm{GDP}, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}*(1.54*\mathrm{ClimSens}**2 + 11.98*\mathrm{ElastESDDriver} + 11.98*\mathrm{GDP}) 3 3
# -----
# Elast_ESD_Driver*(1.5874281*Clim_Sens**2 + Elast_ESD_Driver*(23.22201*GDP - Pop))
# {Elast_ESD_Driver, Clim_Sens, 2, 1.58742810000000, GDP, 23.2220100000000, Pop, -1}
# 1.59 True
# 2 True
# \mathrm{ElastESDDriver} False
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{Pop} False
# 23.22 True
# -1 True
# {1.59, 2, \mathrm{ElastESDDriver}, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{Pop}, 23.22, -1}
# \mathrm{ElastESDDriver}*(1.59*\mathrm{ClimSens}**2 + \mathrm{ElastESDDriver}*(23.22*\mathrm{GDP} - \mathrm{Pop})) 4 4
# -----
# Elast_ESD_Driver*sqrt(GDP)*(1.574641*Clim_Sens**2 + 11.9771509495904*Elast_ESD_Driver + 10.5935475973775)
# {Elast_ESD_Driver, 1/2, 1.57464100000000, Clim_Sens, GDP, 2, 10.5935475973775, 11.9771509495904}
# 1/2 True
# 1.57 True
# 2 True
# \mathrm{ElastESDDriver} False
# 10.59 True
# 11.98 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# {1/2, 1.57, 2, \mathrm{ElastESDDriver}, 10.59, 11.98, \mathrm{GDP}, \mathrm{ClimSens}}
# ...
# 26.96*\mathrm{ClimSens}*\mathrm{ElastESDDriver} - \mathrm{SDR} - 26.96 3 3
# -----
# Elast_ESD_Driver*(4.008167*Clim_Sens**2*Elast_ESD_Driver + 12.508526)
# {Elast_ESD_Driver, Clim_Sens, 2, 4.00816700000000, 12.5085260000000}
# 2 True
# 4.01 True
# \mathrm{ElastESDDriver} False
# 12.51 True
# \mathrm{ClimSens} False
# {2, 4.01, \mathrm{ElastESDDriver}, 12.51, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}*(4.01*\mathrm{ClimSens}**2*\mathrm{ElastESDDriver} + 12.51) 2 3
# -----
# Elast_ESD_Driver**(3/2)*(3.9056087*Clim_Sens**2 + 13.601938)
# {Elast_ESD_Driver, Clim_Sens, 3.90560870000000, 2, 3/2, 13.6019380000000}
# 2 True
# 3.91 True
# \mathrm{ElastESDDriver} False
# 3/2 True
# 13.60 True
# \mathrm{ClimSens} False
# {2, 3.91, \mathrm{ElastESDDriver}, 3/2, 13.60, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}**(3/2)*(3.91*\mathrm{ClimSens}**2 + 13.6) 2 4
# -----
# Elast_ESD_Driver*(3.8699415*Clim_Sens**2 + 48.519978) - SDR - 30.62598
# {Elast_ESD_Driver, -30.6259800000000, 3.86994150000000, Clim_Sens, 2, SDR, 48.5199780000000, -1}
# -30.63 True
# 3.87 True
# 2 True
# \mathrm{ElastESDDriver} False
# 48.52 True
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# -1 True
# {-30.63, 3.87, 2, \mathrm{ElastESDDriver}, 48.52, \mathrm{ClimSens}, \mathrm{SDR}, -1}
# \mathrm{ElastESDDriver}*(3.87*\mathrm{ClimSens}**2 + 48.52) - \mathrm{SDR} - 30.63 3 5
# -----
# Elast_ESD_Driver*(3.9015741*Clim_Sens**2*GDP*(Elast_ESD_Driver - 0.12229905) + 14.749953)
# {-0.122299050000000, Elast_ESD_Driver, Clim_Sens, 3.90157410000000, 2, GDP, 14.7499530000000}
# -0.12 True
# 2 True
# 3.90 True
# \mathrm{ElastESDDriver} False
# 14.75 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# {-0.12, 2, 3.90, \mathrm{ElastESDDriver}, 14.75, \mathrm{GDP}, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}*(3.9*\mathrm{ClimSens}**2*\mathrm{GDP}*(\mathrm{ElastESDDriver} - 0.12) + 14.75) 3 4
# -----
# Elast_ESD_Driver*sqrt(Elast_ESD_Driver*GDP)*(3.9056087*Clim_Sens**2 + 12.0712944)
# {Elast_ESD_Driver, 1/2, 3.90560870000000, Clim_Sens, GDP, 2, 12.0712944000000}
# 1/2 True
# 2 True
# 3.91 True
# \mathrm{ElastESDDriver} False
# 12.07 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# {1/2, 2, 3.91, \mathrm{ElastESDDriver}, 12.07, \mathrm{GDP}, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(3.91*\mathrm{ClimSens}**2 + 12.07) 3 3
# -----
# Elast_ESD_Driver*(4.00981422317761*Clim_Sens**2*GDP*(Elast_ESD_Driver - 0.12229905) + 14.749953)
# {-0.122299050000000, Elast_ESD_Driver, Clim_Sens, 2, 4.00981422317761, GDP, 14.7499530000000}
# -0.12 True
# 2 True
# 4.01 True
# \mathrm{ElastESDDriver} False
# 14.75 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# {-0.12, 2, 4.01, \mathrm{ElastESDDriver}, 14.75, \mathrm{GDP}, \mathrm{ClimSens}}
# \mathrm{ElastESDDriver}*(4.01*\mathrm{ClimSens}**2*\mathrm{GDP}*(\mathrm{ElastESDDriver} - 0.12) + 14.75) 3 4
# -----
# Elast_ESD_Driver*sqrt(Elast_ESD_Driver*GDP)*(3.9056087*Clim_Sens**2 - 0.5004509*SDR + 13.601938)
# {-0.500450900000000, Elast_ESD_Driver, 1/2, 3.90560870000000, Clim_Sens, GDP, 2, SDR, 13.6019380000000}
# -0.50 True
# 1/2 True
# 2 True
# 3.91 True
# \mathrm{ElastESDDriver} False
# 13.60 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {-0.50, 1/2, 2, 3.91, \mathrm{ElastESDDriver}, 13.60, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{SDR}}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{ElastESDDriver}*\mathrm{GDP})*(3.91*\mathrm{ClimSens}**2 - 0.5*\mathrm{SDR} + 13.6) 4 4
# -----
# Forcing
# {Forcing}
# \mathrm{Forcing} False
# {\mathrm{Forcing}}
# \mathrm{Forcing} 1 0
# -----
# 3.20740611709836
# {3.20740611709836}
# 3.21 True
# {3.21}
# 3.21 0 1
# -----
# 7.736143 - Clim_Sens
# {Clim_Sens, -1, 7.73614300000000}
# \mathrm{ClimSens} False
# -1 True
# 7.74 True
# {\mathrm{ClimSens}, -1, 7.74}
# 7.74 - \mathrm{ClimSens} 1 2
# -----
# -62.77741 + 197.10954/Clim_Sens
# {-62.7774100000000, 197.109540000000, -1, Clim_Sens}
# \mathrm{ClimSens} False
# -62.78 True
# 197.11 True
# -1 True
# {\mathrm{ClimSens}, -62.78, 197.11, -1}
# -62.78 + 197.11/\mathrm{ClimSens} 1 3
# -----
# Clim_Sens - 69.008316 + 206.37889/Clim_Sens
# {Clim_Sens, -69.0083160000000, 206.378890000000, -1}
# \mathrm{ClimSens} False
# -69.01 True
# 206.38 True
# -1 True
# {\mathrm{ClimSens}, -69.01, 206.38, -1}
# \mathrm{ClimSens} - 69.01 + 206.38/\mathrm{ClimSens} 1 3
# -----
# Clim_Sens - 58.702164 + 151.356/(Clim_Sens - 0.39419633)
# {-0.394196330000000, Clim_Sens, -58.7021640000000, 151.356000000000, -1}
# -0.39 True
# -58.70 True
# \mathrm{ClimSens} False
# 151.36 True
# -1 True
# {-0.39, -58.70, \mathrm{ClimSens}, 151.36, -1}
# ((\mathrm{ClimSens} - 58.7)*(\mathrm{ClimSens} - 0.39) + 151.36)/(\mathrm{ClimSens} - 0.39) 1 4
# -----
# 7.36816293250903*Clim_Sens - 109.6503 + 265.2593/Clim_Sens
# {Clim_Sens, 7.36816293250903, 265.259300000000, -109.650300000000, -1}
# 7.37 True
# 265.26 True
# \mathrm{ClimSens} False
# -109.65 True
# -1 True
# {7.37, 265.26, \mathrm{ClimSens}, -109.65, -1}
# 7.37*\mathrm{ClimSens} - 109.65 + 265.26/\mathrm{ClimSens} 1 4
# -----
# -57.22161 + 133.90697/(Clim_Sens - 0.500151) + 6.520531/Biomass_Poten
# {-0.500151000000000, Clim_Sens, 133.906970000000, 6.52053100000000, -57.2216100000000, Biomass_Poten, -1}
# -0.50 True
# 133.91 True
# 6.52 True
# -57.22 True
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# -1 True
# {-0.50, 133.91, 6.52, -57.22, \mathrm{ClimSens}, \mathrm{BiomassPoten}, -1}
# -57.22 + 133.91/(\mathrm{ClimSens} - 0.5) + 6.52/\mathrm{BiomassPoten} 2 5
# -----
# 7.36816293250903*Clim_Sens*sqrt(0.0184196578272264*SDR + 1) - 109.6503 + 265.2593/Clim_Sens
# {1, Clim_Sens, 1/2, 7.36816293250903, 265.259300000000, SDR, -109.650300000000, 0.0184196578272264, -1}
# 0.02 True
# 1 True
# 1/2 True
# 7.37 True
# 265.26 True
# \mathrm{ClimSens} False
# -109.65 True
# \mathrm{SDR} False
# -1 True
# {0.02, 1, 1/2, 7.37, 265.26, \mathrm{ClimSens}, -109.65, \mathrm{SDR}, -1}
# 7.37*\mathrm{ClimSens}*sqrt(0.02*\mathrm{SDR} + 1) - 109.65 + 265.26/\mathrm{ClimSens} 2 7
# -----
# sqrt(Other_ESD_Drivers)*(7.36816293250903*Clim_Sens + Elast_ESD_Driver - 109.6503 + 265.2593/Clim_Sens)
# {Other_ESD_Drivers, Elast_ESD_Driver, 1/2, Clim_Sens, 7.36816293250903, 265.259300000000, -109.650300000000, -1}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 7.37 True
# 265.26 True
# \mathrm{ClimSens} False
# -109.65 True
# \mathrm{OtherESDDrivers} False
# -1 True
# {1/2, \mathrm{ElastESDDriver}, 7.37, 265.26, \mathrm{ClimSens}, -109.65, \mathrm{OtherESDDrivers}, -1}
# sqrt(\mathrm{OtherESDDrivers})*(\mathrm{ClimSens}*(7.37*\mathrm{ClimSens} + \mathrm{ElastESDDriver} - 109.65) + 265.26)/\mathrm{ClimSens} 3 4
# -----
# Other_ESD_Drivers**(1/4)*(7.36816293250903*Clim_Sens + Elast_ESD_Driver - 109.6503 + 265.2593/Clim_Sens)
# {Other_ESD_Drivers, Elast_ESD_Driver, Clim_Sens, 7.36816293250903, 265.259300000000, 1/4, -109.650300000000, -1}
# \mathrm{ElastESDDriver} False
# 7.37 True
# 265.26 True
# \mathrm{ClimSens} False
# 1/4 True
# -109.65 True
# \mathrm{OtherESDDrivers} False
# -1 True
# {\mathrm{ElastESDDriver}, 7.37, 265.26, \mathrm{ClimSens}, 1/4, -109.65, \mathrm{OtherESDDrivers}, -1}
# \mathrm{OtherESDDrivers}**(1/4)*(\mathrm{ClimSens}*(7.37*\mathrm{ClimSens} + \mathrm{ElastESDDriver} - 109.65) + 265.26)/\mathrm{ClimSens} 3 4
# -----
# -Biomass_Poten + 8.414561*Clim_Sens - 114.1866629 + 275.0882/Clim_Sens
# {Clim_Sens, 8.41456100000000, -114.186662900000, 275.088200000000, Biomass_Poten, -1}
# 8.41 True
# -114.19 True
# \mathrm{ClimSens} False
# 275.09 True
# \mathrm{BiomassPoten} False
# -1 True
# {8.41, -114.19, \mathrm{ClimSens}, 275.09, \mathrm{BiomassPoten}, -1}
# -\mathrm{BiomassPoten} + 8.41*\mathrm{ClimSens} - 114.19 + 275.09/\mathrm{ClimSens} 2 4
# -----
# -2*Biomass_Poten + 7.1339664*Clim_Sens - 104.63350642 + 262.225162893306/Clim_Sens
# {Clim_Sens, 262.225162893306, 7.13396640000000, Biomass_Poten, -1, -104.633506420000, -2}
# 262.23 True
# 7.13 True
# \mathrm{ClimSens} False
# -1 True
# -104.63 True
# \mathrm{BiomassPoten} False
# -2 True
# {262.23, 7.13, \mathrm{ClimSens}, -1, -104.63, \mathrm{BiomassPoten}, -2}
# -2*\mathrm{BiomassPoten} + 7.13*\mathrm{ClimSens} - 104.63 + 262.23/\mathrm{ClimSens} 2 5
# -----
# Solar_PV_Inv_Cost
# {Solar_PV_Inv_Cost}
# \mathrm{SolarPVInvCost} False
# {\mathrm{SolarPVInvCost}}
# \mathrm{SolarPVInvCost} 1 0
# -----
# sqrt(SDR)
# {1/2, SDR}
# \mathrm{SDR} False
# 1/2 True
# {\mathrm{SDR}, 1/2}
# sqrt(\mathrm{SDR}) 1 1
# -----
# 824.7326*Elast_ESD_Driver
# {824.732600000000, Elast_ESD_Driver}
# 824.73 True
# \mathrm{ElastESDDriver} False
# {824.73, \mathrm{ElastESDDriver}}
# 824.73*\mathrm{ElastESDDriver} 1 1
# -----
# Clim_Sens + 821.61755*Elast_ESD_Driver
# {Elast_ESD_Driver, Clim_Sens, 821.617550000000}
# \mathrm{ClimSens} False
# 821.62 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, 821.62, \mathrm{ElastESDDriver}}
# \mathrm{ClimSens} + 821.62*\mathrm{ElastESDDriver} 2 1
# -----
# Elast_ESD_Driver*(72.486496*Clim_Sens + 592.19476)
# {592.194760000000, Elast_ESD_Driver, Clim_Sens, 72.4864960000000}
# 592.19 True
# \mathrm{ClimSens} False
# 72.49 True
# \mathrm{ElastESDDriver} False
# {592.19, \mathrm{ClimSens}, 72.49, \mathrm{ElastESDDriver}}
# \mathrm{ElastESDDriver}*(72.49*\mathrm{ClimSens} + 592.19) 2 2
# -----
# Elast_ESD_Driver*(73.41893*Clim_Sens + 597.9221) - SDR
# {Elast_ESD_Driver, Clim_Sens, 73.4189300000000, SDR, 597.922100000000, -1}
# \mathrm{ElastESDDriver} False
# 73.42 True
# \mathrm{ClimSens} False
# 597.92 True
# \mathrm{SDR} False
# -1 True
# {\mathrm{ElastESDDriver}, 73.42, \mathrm{ClimSens}, 597.92, \mathrm{SDR}, -1}
# \mathrm{ElastESDDriver}*(73.42*\mathrm{ClimSens} + 597.92) - \mathrm{SDR} 3 3
# -----
# Elast_ESD_Driver*(78.24178*Clim_Sens + 538.36145*GDP) + Wind_Poten
# {Elast_ESD_Driver, Clim_Sens, GDP, Wind_Poten, 78.2417800000000, 538.361450000000}
# \mathrm{ElastESDDriver} False
# 78.24 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 538.36 True
# \mathrm{WindPoten} False
# {\mathrm{ElastESDDriver}, 78.24, \mathrm{GDP}, \mathrm{ClimSens}, 538.36, \mathrm{WindPoten}}
# \mathrm{ElastESDDriver}*(78.24*\mathrm{ClimSens} + 538.36*\mathrm{GDP}) + \mathrm{WindPoten} 4 2
# -----
# Elast_ESD_Driver*sqrt(GDP)*(73.97994*Clim_Sens + 564.46182)
# {Elast_ESD_Driver, 1/2, Clim_Sens, GDP, 73.9799400000000, 564.461820000000}
# 1/2 True
# \mathrm{ElastESDDriver} False
# 73.98 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 564.46 True
# {1/2, \mathrm{ElastESDDriver}, 73.98, \mathrm{GDP}, \mathrm{ClimSens}, 564.46}
# \mathrm{ElastESDDriver}*sqrt(\mathrm{GDP})*(73.98*\mathrm{ClimSens} + 564.46) 3 2
# -----
# Biomass_Poten + Elast_ESD_Driver*(73.97994*Clim_Sens + 357.1252*GDP + 207.33662)
# {Elast_ESD_Driver, Clim_Sens, 357.125200000000, GDP, 73.9799400000000, 207.336620000000, Biomass_Poten}
# 357.13 True
# \mathrm{ElastESDDriver} False
# 73.98 True
# 207.34 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# {357.13, \mathrm{ElastESDDriver}, 73.98, 207.34, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{BiomassPoten}}
# \mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(73.98*\mathrm{ClimSens} + 357.13*\mathrm{GDP} + 207.34) 4 3
# -----
# Biomass_Poten + Elast_ESD_Driver*(Biomass_Poten + 73.97994*Clim_Sens + 357.1252*GDP + 207.33662)
# {Elast_ESD_Driver, Clim_Sens, 357.125200000000, GDP, 73.9799400000000, 207.336620000000, Biomass_Poten}
# 357.13 True
# \mathrm{ElastESDDriver} False
# 73.98 True
# 207.34 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{BiomassPoten} False
# {357.13, \mathrm{ElastESDDriver}, 73.98, 207.34, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{BiomassPoten}}
# \mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(\mathrm{BiomassPoten} + 73.98*\mathrm{ClimSens} + 357.13*\mathrm{GDP} + 207.34) 4 3
# -----
# 58.381542*Biomass_Poten + Elast_ESD_Driver*(73.97994*Clim_Sens + 357.1252*GDP + 207.33662) - 58.381542*Elast_ESD_Price
# {Elast_ESD_Driver, Clim_Sens, 357.125200000000, -58.3815420000000, GDP, 73.9799400000000, 207.336620000000, Elast_ESD_Price, Biomass_Poten, 58.3815420000000}
# 357.13 True
# \mathrm{ElastESDDriver} False
# -58.38 True
# 73.98 True
# 207.34 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# 58.38 True
# {357.13, \mathrm{ElastESDDriver}, -58.38, 73.98, 207.34, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, 58.38}
# 58.38*\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(73.98*\mathrm{ClimSens} + 357.13*\mathrm{GDP} + 207.34) - 58.38*\mathrm{ElastESDPrice} 5 5
# -----
# 58.381542*Biomass_Poten + Elast_ESD_Driver*(73.97994*Clim_Sens + 357.1252*GDP + 207.33662) - 58.381542*sqrt(Elast_ESD_Price)
# {1/2, Elast_ESD_Driver, Clim_Sens, 357.125200000000, -58.3815420000000, GDP, 73.9799400000000, 207.336620000000, Elast_ESD_Price, Biomass_Poten, 58.3815420000000}
# 1/2 True
# 357.13 True
# -58.38 True
# \mathrm{ElastESDDriver} False
# 73.98 True
# 207.34 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{ElastESDPrice} False
# \mathrm{BiomassPoten} False
# 58.38 True
# {1/2, 357.13, -58.38, \mathrm{ElastESDDriver}, 73.98, 207.34, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{ElastESDPrice}, \mathrm{BiomassPoten}, 58.38}
# 58.38*\mathrm{BiomassPoten} + \mathrm{ElastESDDriver}*(73.98*\mathrm{ClimSens} + 357.13*\mathrm{GDP} + 207.34) - 58.38*sqrt(\mathrm{ElastESDPrice}) 5 6
# -----
# Clim_Sens*(23.744751*Clim_Sens - 86.21939) + 901.00793*Elast_ESD_Driver - Elast_ESD_Price + 157.58218 - 220.93672/GDP
# {Elast_ESD_Driver, Clim_Sens, -220.936720000000, 901.007930000000, GDP, -86.2193900000000, Elast_ESD_Price, 23.7447510000000, 157.582180000000, -1}
# -220.94 True
# 901.01 True
# \mathrm{ElastESDDriver} False
# -86.22 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# 23.74 True
# \mathrm{ElastESDPrice} False
# 157.58 True
# -1 True
# {-220.94, 901.01, \mathrm{ElastESDDriver}, -86.22, \mathrm{GDP}, \mathrm{ClimSens}, 23.74, \mathrm{ElastESDPrice}, 157.58, -1}
# (\mathrm{GDP}*(\mathrm{ClimSens}*(23.74*\mathrm{ClimSens} - 86.22) + 901.01*\mathrm{ElastESDDriver} - \mathrm{ElastESDPrice} + 157.58) - 220.94)/\mathrm{GDP} 4 6
# -----
# -0.0461336800000000
# {-0.0461336800000000}
# -0.05 True
# {-0.05}
# -0.05 0 1
# -----
# sqrt(Clim_Sens)
# {1/2, Clim_Sens}
# \mathrm{ClimSens} False
# 1/2 True
# {\mathrm{ClimSens}, 1/2}
# sqrt(\mathrm{ClimSens}) 1 1
# -----
# Clim_Sens + 31.660868
# {Clim_Sens, 31.6608680000000}
# \mathrm{ClimSens} False
# 31.66 True
# {\mathrm{ClimSens}, 31.66}
# \mathrm{ClimSens} + 31.66 1 1
# -----
# Clim_Sens*(Clim_Sens + 7.6293163)
# {Clim_Sens, 7.62931630000000}
# \mathrm{ClimSens} False
# 7.63 True
# {\mathrm{ClimSens}, 7.63}
# \mathrm{ClimSens}*(\mathrm{ClimSens} + 7.63) 1 1
# -----
# Clim_Sens*Elast_ESD_Driver*(Clim_Sens + 7.8337374)
# {Elast_ESD_Driver, Clim_Sens, 7.83373740000000}
# \mathrm{ClimSens} False
# \mathrm{ElastESDDriver} False
# 7.83 True
# {\mathrm{ClimSens}, \mathrm{ElastESDDriver}, 7.83}
# \mathrm{ClimSens}*\mathrm{ElastESDDriver}*(\mathrm{ClimSens} + 7.83) 2 1
# -----
# Clim_Sens*Elast_ESD_Driver*(Clim_Sens*GDP + 7.6293163)
# {Elast_ESD_Driver, Clim_Sens, GDP, 7.62931630000000}
# \mathrm{ClimSens} False
# \mathrm{GDP} False
# \mathrm{ElastESDDriver} False
# 7.63 True
# {\mathrm{ClimSens}, \mathrm{GDP}, \mathrm{ElastESDDriver}, 7.63}
# \mathrm{ClimSens}*\mathrm{ElastESDDriver}*(\mathrm{ClimSens}*\mathrm{GDP} + 7.63) 3 1
# -----
# Clim_Sens + Elast_ESD_Driver*(2*Clim_Sens**2 + 11.099661)
# {2, Elast_ESD_Driver, Clim_Sens, 11.0996610000000}
# \mathrm{ClimSens} False
# 2 True
# 11.10 True
# \mathrm{ElastESDDriver} False
# {\mathrm{ClimSens}, 2, 11.10, \mathrm{ElastESDDriver}}
# \mathrm{ClimSens} + \mathrm{ElastESDDriver}*(2*\mathrm{ClimSens}**2 + 11.1) 2 2
# -----
# 1.06704596593936*Elast_ESD_Driver*(2*Clim_Sens**2 + 8.191311) + 1.06704596593936*SDR
# {1.06704596593936, 2, Elast_ESD_Driver, Clim_Sens, 8.19131100000000, SDR}
# 1.07 True
# 2 True
# \mathrm{ElastESDDriver} False
# 8.19 True
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# {1.07, 2, \mathrm{ElastESDDriver}, 8.19, \mathrm{ClimSens}, \mathrm{SDR}}
# 1.07*\mathrm{ElastESDDriver}*(2*\mathrm{ClimSens}**2 + 8.19) + 1.07*\mathrm{SDR} 3 3
# -----
# 1.06704596593936*Elast_ESD_Driver*(Clim_Sens*(Clim_Sens*GDP + Clim_Sens) + 8.191311) + 1.06704596593936*SDR - 1.15471275522739
# {1.06704596593936, Elast_ESD_Driver, Clim_Sens, GDP, 8.19131100000000, SDR, -1.15471275522739}
# 1.07 True
# 2 True
# 1 True
# \mathrm{ElastESDDriver} False
# 8.19 True
# \mathrm{GDP} False
# \mathrm{ClimSens} False
# \mathrm{SDR} False
# -1.15 True
# {1.07, 2, 1, \mathrm{ElastESDDriver}, 8.19, \mathrm{GDP}, \mathrm{ClimSens}, \mathrm{SDR}, -1.15}
# 1.07*\mathrm{ElastESDDriver}*(\mathrm{ClimSens}**2*(\mathrm{GDP} + 1) + 8.19) + 1.07*\mathrm{SDR} - 1.15 4 3
# -----
